# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Automobile.csv')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
df.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
df.sample()
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 65         -1                 93  mercedes-benz    diesel      turbo
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 65            four      wagon          rwd           front       110.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 65          183          idi  3.58    3.64              21.5        123
#
#     peak_rpm city_mpg  highway_mpg  price
# 65      4350       22           25  28248
#
# [1 rows x 26 columns]

# %%
df.sample(5)
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 24           1                148       dodge       gas        std
# 83           1                125  mitsubishi       gas        std
# 118          1                154    plymouth       gas        std
# 176         -1                 90      toyota       gas        std
# 87           1                128      nissan    diesel        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 24             four      sedan          fwd           front        93.7  ...
# 83             four      sedan          fwd           front        96.3  ...
# 118            four      sedan          fwd           front        93.7  ...
# 176            four      sedan          rwd           front       104.5  ...
# 87              two      sedan          fwd           front        94.5  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.shape
# Out:
# (201, 26)

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.iloc[1]
# Out:
# symboling                        3
# normalized_losses              168
# make                   alfa-romero
# fuel_type                      gas
# aspiration                     std
# number_of_doors                two
# body_style             convertible
# drive_wheels                   rwd
# engine_location              front
# wheel_base                    88.6
# length                       168.8
# width                         64.1
# height                        48.8
# curb_weight                   2548
# engine_type                   dohc
# number_of_cylinders           four
# engine_size                    130
# fuel_system                   mpfi
# bore                          3.47
# stroke                        2.68
# compression_ratio              9.0
# horsepower                     111
# peak_rpm                      5000
# city_mpg                        21
# highway_mpg                     27
# price                        16500
# Name: 1, dtype: object

# %%
df.iloc[0]['fuel_type']
# Out:
# 'gas'

# %%
df.iloc[4:6]
# Out:
#    symboling  normalized_losses  make fuel_type aspiration number_of_doors  \
# 4          2                164  audi       gas        std            four
# 5          2                161  audi       gas        std             two
#
#   body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 4      sedan          4wd           front        99.4  ...          136
# 5      sedan          fwd           front        99.8  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 4         mpfi  3.19     3.4               8.0        115      5500       18
# 5         mpfi  3.19     3.4               8.5        110      5500       19
#
#    highway_mpg  price
# 4           22  17450
# 5           25  15250
#
# [2 rows x 26 columns]

# %%
df.iloc[:,1:6]
# Out:
#      normalized_losses         make fuel_type aspiration number_of_doors
# 0                  168  alfa-romero       gas        std             two
# 1                  168  alfa-romero       gas        std             two
# 2                  168  alfa-romero       gas        std             two
# 3                  164         audi       gas        std            four
# 4                  164         audi       gas        std            four
# ..                 ...          ...       ...        ...             ...
# 196                 95        volvo       gas        std            four
# 197                 95        volvo       gas      turbo            four
# 198                 95        volvo       gas        std            four
# 199                 95        volvo    diesel      turbo            four
# 200                 95        volvo       gas      turbo            four
#
# [201 rows x 5 columns]

# %%
df.loc[5]
# Out:
# symboling                  2
# normalized_losses        161
# make                    audi
# fuel_type                gas
# aspiration               std
# number_of_doors          two
# body_style             sedan
# drive_wheels             fwd
# engine_location        front
# wheel_base              99.8
# length                 177.3
# width                   66.3
# height                  53.1
# curb_weight             2507
# engine_type              ohc
# number_of_cylinders     five
# engine_size              136
# fuel_system             mpfi
# bore                    3.19
# stroke                   3.4
# compression_ratio        8.5
# horsepower               110
# peak_rpm                5500
# city_mpg                  19
# highway_mpg               25
# price                  15250
# Name: 5, dtype: object

# %%
df[df.price>12000]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df[(df.fuel_type=="gas")&(df.price>5000)]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 74        volvo       gas      turbo
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.sort_values('wheel_base',ascending=False)
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 70           0                140  mercedes-benz       gas        std
# 68          -1                122  mercedes-benz       gas        std
# 67          -1                 93  mercedes-benz    diesel      turbo
# 111          0                161         peugot    diesel      turbo
# 110          0                161         peugot       gas        std
# ..         ...                ...            ...       ...        ...
# 1            3                168    alfa-romero       gas        std
# 0            3                168    alfa-romero       gas        std
# 17           2                121      chevrolet       gas        std
# 30           2                137          honda       gas        std
# 29           2                137          honda       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
df.sort_values('symboling',ascending=True)
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 194         -2                103          volvo       gas      turbo
# 192         -2                103          volvo       gas        std
# 190         -2                103          volvo       gas        std
# 200         -1                 95          volvo       gas      turbo
# 67          -1                 93  mercedes-benz    diesel      turbo
# ..         ...                ...            ...       ...        ...
# 128          3                150           saab       gas        std
# 130          3                150           saab       gas        std
# 132          3                150           saab       gas      turbo
# 54           3                150          mazda       gas        std
# 0            3                168    alfa-romero       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
df[df.price>500].sort_index(ascending=False)
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 200         -1                 95        volvo       gas      turbo
# 199         -1                 95        volvo    diesel      turbo
# 198         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 196         -1                 95        volvo       gas        std
# ..         ...                ...          ...       ...        ...
# 4            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 2            1                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 0            3                168  alfa-romero       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 200            four        sedan          rwd           front       109.1
# ...

# %% [markdown]
# #### Ranking

# %%
df['price']=df.fuel_type.rank(method='max')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df['price']=df.fuel_type.rank(method='dense')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df['price']=df.fuel_type.rank()
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ### Duplicates

# %%
df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Length: 201, dtype: bool

# %%
df1=df[df.duplicated(keep=False)]
df1
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, number_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, number_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# #### Reshaping Dataframe

# %%
details={'name':["camila","shakira","taylor","selena"],
        'salary':[80000,90000,45000,200000],
         'age':[29,30,35,24],
         'gender':["F","F","F","F"]
        }

# %%
df_emp=pd.DataFrame(details)
df_emp
# Out:
#       name  salary  age gender
# 0   camila   80000   29      F
# 1  shakira   90000   30      F
# 2   taylor   45000   35      F
# 3   selena  200000   24      F

# %% [markdown]
# #### melt()

# %%
df_melt=df_emp.melt(id_vars=["gender"])
df_melt
# Out:
#    gender variable    value
# 0       F     name   camila
# 1       F     name  shakira
# 2       F     name   taylor
# 3       F     name   selena
# 4       F   salary    80000
# 5       F   salary    90000
# 6       F   salary    45000
# 7       F   salary   200000
# 8       F      age       29
# 9       F      age       30
# 10      F      age       35
# 11      F      age       24

# %%
df_melt=df_emp.melt(id_vars=["gender"],value_vars=["age"])
df_melt
# Out:
#   gender variable  value
# 0      F      age     29
# 1      F      age     30
# 2      F      age     35
# 3      F      age     24

# %% [markdown]
# #### Pivot tables

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
pd.pivot_table(df,index="fuel_type",values="price")
# Out:
#            price
# fuel_type
# diesel      10.5
# gas        111.0

# %%
pd.pivot_table(df,index="fuel_type",values="price",aggfunc="sum")
# Out:
#              price
# fuel_type
# diesel       210.0
# gas        20091.0

# %% [markdown]
# #### Cross table

# %%
details
# Out:
# {'name': ['camila', 'shakira', 'taylor', 'selena'],
#  'salary': [80000, 90000, 45000, 200000],
#  'age': [29, 30, 35, 24],
#  'gender': ['F', 'F', 'F', 'F']}

# %%
df_emp
# Out:
#       name  salary  age gender
# 0   camila   80000   29      F
# 1  shakira   90000   30      F
# 2   taylor   45000   35      F
# 3   selena  200000   24      F

# %%
pd.crosstab(df_emp.name,df_emp.age,rownames=["Name"],colnames=["Age"])
# Out:
# Age      24  29  30  35
# Name
# camila    0   1   0   0
# selena    1   0   0   0
# shakira   0   0   1   0
# taylor    0   0   0   1

# %% [markdown]
# #### Dataframe concatenation

# %%
s1={
    "name":["declan","justin","Shawn","Zayn"],
    "order":[1001,1002,1003,1004],
    "quantity":[30,20,5,15],
    "price":[100,300,500,1000]
}

# %%
s2={
    "name":["alan walker","porch bella","nick","Charlie"],
    "order":[1001,1002,1003,1004],
    "quantity":[250,360,53,85],
    "price":[1000,3000,5000,10000]
}

# %%
df_s1=pd.DataFrame(s1)
df_s1
# Out:
#      name  order  quantity  price
# 0  declan   1001        30    100
# 1  justin   1002        20    300
# 2   Shawn   1003         5    500
# 3    Zayn   1004        15   1000

# %%
df_s2=pd.DataFrame(s2)
df_s2
# Out:
#           name  order  quantity  price
# 0  alan walker   1001       250   1000
# 1  porch bella   1002       360   3000
# 2         nick   1003        53   5000
# 3      Charlie   1004        85  10000

# %%
df_s=pd.concat([df_s1,df_s2])
df_s
# Out:
#           name  order  quantity  price
# 0       declan   1001        30    100
# 1       justin   1002        20    300
# 2        Shawn   1003         5    500
# 3         Zayn   1004        15   1000
# 0  alan walker   1001       250   1000
# 1  porch bella   1002       360   3000
# 2         nick   1003        53   5000
# 3      Charlie   1004        85  10000

# %%
df_s1.append(df_s2)
# Out:
#           name  order  quantity  price
# 0       declan   1001        30    100
# 1       justin   1002        20    300
# 2        Shawn   1003         5    500
# 3         Zayn   1004        15   1000
# 0  alan walker   1001       250   1000
# 1  porch bella   1002       360   3000
# 2         nick   1003        53   5000
# 3      Charlie   1004        85  10000

# %%
df_s=pd.concat([df_s1,df_s2],axis=1)
df_s
# Out:
#      name  order  quantity  price         name  order  quantity  price
# 0  declan   1001        30    100  alan walker   1001       250   1000
# 1  justin   1002        20    300  porch bella   1002       360   3000
# 2   Shawn   1003         5    500         nick   1003        53   5000
# 3    Zayn   1004        15   1000      Charlie   1004        85  10000

# %% [markdown]
# #### Dataframe Joins

# %%
c1={
    "id":[1,2,3,4],
    "name":["sha","sow","kan","swa"]
}
df_c1=pd.DataFrame(c1)
df_c1
# Out:
#    id name
# 0   1  sha
# 1   2  sow
# 2   3  kan
# 3   4  swa

# %%
c2={
    "ord_id":[101,102,103,104],
    "id":[1,2,3,4],
    "order":[701,702,703,704],
    "pay":["pod","cod","gpay","paytm"]
}
df_c2=pd.DataFrame(c2)
df_c2
# Out:
#    ord_id  id  order    pay
# 0     101   1    701    pod
# 1     102   2    702    cod
# 2     103   3    703   gpay
# 3     104   4    704  paytm

# %%
df_c1.set_index('id').join(df_c2.set_index('id'), on='id',how='inner')
# Out:
#    name  ord_id  order    pay
# id
# 1   sha     101    701    pod
# 2   sow     102    702    cod
# 3   kan     103    703   gpay
# 4   swa     104    704  paytm

# %% [markdown]
# #### Merge

# %%
pd.merge(df_c1,df_c2,on="id")
# Out:
#    id name  ord_id  order    pay
# 0   1  sha     101    701    pod
# 1   2  sow     102    702    cod
# 2   3  kan     103    703   gpay
# 3   4  swa     104    704  paytm

# %%
pd.merge(df_c1,df_c2,on="id",how="outer")
# Out:
#    id name  ord_id  order    pay
# 0   1  sha     101    701    pod
# 1   2  sow     102    702    cod
# 2   3  kan     103    703   gpay
# 3   4  swa     104    704  paytm

# %%
pd.merge(df_c1,df_c2,on="id",how="right")
# Out:
#    id name  ord_id  order    pay
# 0   1  sha     101    701    pod
# 1   2  sow     102    702    cod
# 2   3  kan     103    703   gpay
# 3   4  swa     104    704  paytm

# %%
pd.merge(df_c1,df_c2,on="id",how="left")
# Out:
#    id name  ord_id  order    pay
# 0   1  sha     101    701    pod
# 1   2  sow     102    702    cod
# 2   3  kan     103    703   gpay
# 3   4  swa     104    704  paytm

# %%
pd.merge(df_c1,df_c2,left_index=True,right_index=True)
# Out:
#    id_x name  ord_id  id_y  order    pay
# 0     1  sha     101     1    701    pod
# 1     2  sow     102     2    702    cod
# 2     3  kan     103     3    703   gpay
# 3     4  swa     104     4    704  paytm

# %%
df_s1
# Out:
#      name  order  quantity  price
# 0  declan   1001        30    100
# 1  justin   1002        20    300
# 2   Shawn   1003         5    500
# 3    Zayn   1004        15   1000

# %%
df_s1.head(3)
# Out:
#      name  order  quantity  price
# 0  declan   1001        30    100
# 1  justin   1002        20    300
# 2   Shawn   1003         5    500

# %% [markdown]
# ### duplicates

# %%
dup={
    "id":[1,2,3,4,1,2,3,4],
    "name":["sha","sow","kan","swa","sha","sow","kan","swa"]
}
df_dup=pd.DataFrame(dup)
df_dup
# Out:
#    id name
# 0   1  sha
# 1   2  sow
# 2   3  kan
# 3   4  swa
# 4   1  sha
# 5   2  sow
# 6   3  kan
# 7   4  swa

# %% [markdown]
# #### checking duplicates

# %%
df_dup.duplicated(keep=False)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# dtype: bool

# %%
df1_dup=df_dup[df_dup.duplicated(keep=False)]
df1_dup
# Out:
#    id name
# 0   1  sha
# 1   2  sow
# 2   3  kan
# 3   4  swa
# 4   1  sha
# 5   2  sow
# 6   3  kan
# 7   4  swa

# %% [markdown]
# #### dropping duplicates

# %%
df1_dup.drop_duplicates()
# Out:
#    id name
# 0   1  sha
# 1   2  sow
# 2   3  kan
# 3   4  swa

# %% [markdown]
# #### replace the values

# %%
dup=df1_dup.replace(to_replace=["sha","sow","kan","swa"],\
               value=["Sha","Sow","Kani","Swas"])
dup
# Out:
#    id  name
# 0   1   Sha
# 1   2   Sow
# 2   3  Kani
# 3   4  Swas
# 4   1   Sha
# 5   2   Sow
# 6   3  Kani
# 7   4  Swas

# %%
df_dup_drop=dup.drop_duplicates()
df_dup_drop
# Out:
#    id  name
# 0   1   Sha
# 1   2   Sow
# 2   3  Kani
# 3   4  Swas

# %%
df_dup_drop
# Out:
#    id  name
# 0   1   Sha
# 1   2   Sow
# 2   3  Kani
# 3   4  Swas

# %%
grouping=df.groupby(['fuel_type'])
for fuel_type,fuel_df in grouping:
    print(fuel_type)
    print(fuel_df.head(1))
# Out:
# diesel
#     symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 60          0                119  mazda    diesel        std            four
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 60      sedan          fwd           front        98.8  ...          122
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 60          idi  3.39    3.39              22.7         64      4650       36
#
#     highway_mpg  price
# 60           42  10795
#
# [1 rows x 26 columns]
# gas
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# #### to find whether there are missing values

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# #### checking colns

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')
